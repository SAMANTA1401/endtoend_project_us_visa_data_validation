# %%
import pandas as pd
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# d:\a27_YEARS_OLD\data__validation\venv\Lib\site-packages\evidently\analyzers\__init__.py:3: UserWarning: analyzers are deprecated, use metrics instead
#   warnings.warn("analyzers are deprecated, use metrics instead")
# d:\a27_YEARS_OLD\data__validation\venv\Lib\site-packages\evidently\dashboard\__init__.py:8: UserWarning: dashboards are deprecated, use metrics instead
#   warnings.warn("dashboards are deprecated, use metrics instead")
# d:\a27_YEARS_OLD\data__validation\venv\Lib\site-packages\evidently\tabs\__init__.py:8: UserWarning: 'import evidently.tabs' is deprecated, use 'import evidently.dashboard.tabs'
#   warnings.warn(
# d:\a27_YEARS_OLD\data__validation\venv\Lib\site-packages\evidently\model_profile\__init__.py:8: UserWarning: model profiles are deprecated, use metrics instead
#   warnings.warn("model profiles are deprecated, use metrics instead")
# ...

# %%
data = pd.read_csv("../artifacts/EasyVisa.csv")

# %%
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# Data Drift Dashboard

# %%
data.shape
# Out:
# (25480, 12)

# %%
data[:400]
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 0     EZYV01           Asia           High School                  N
# 1     EZYV02           Asia              Master's                  Y
# 2     EZYV03           Asia            Bachelor's                  N
# 3     EZYV04           Asia            Bachelor's                  N
# 4     EZYV05         Africa              Master's                  Y
# ..       ...            ...                   ...                ...
# 395  EZYV396  North America            Bachelor's                  Y
# 396  EZYV397  North America           High School                  Y
# 397  EZYV398         Europe             Doctorate                  Y
# 398  EZYV399           Asia              Master's                  Y
# 399  EZYV400           Asia              Master's                  N
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %%
data[401:500]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 201  EZYV202      Asia            Bachelor's                  Y
# 202  EZYV203      Asia            Bachelor's                  Y
# 203  EZYV204      Asia              Master's                  N
# 204  EZYV205      Asia           High School                  Y
# 205  EZYV206      Asia           High School                  Y
# ..       ...       ...                   ...                ...
# 295  EZYV296      Asia              Master's                  Y
# 296  EZYV297    Europe            Bachelor's                  Y
# 297  EZYV298      Asia           High School                  N
# 298  EZYV299      Asia            Bachelor's                  N
# 299  EZYV300      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 201                     N             1313         2002                 West
# ...

# %%
data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])

# %%
data_drift_dashboard.calculate(data[:400], data[401:500])
# Out:
# d:\a27_YEARS_OLD\data__validation\venv\Lib\site-packages\scipy\stats\_stats_py.py:7654: RuntimeWarning:
#
# divide by zero encountered in divide

# %%
data_drift_dashboard.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
# ...

# %%
data_drift_dashboard.save("boston_data_drift_report.html")

# %%
data_drift_profile = Profile(sections=[DataDriftProfileSection()])

# %%
data_drift_profile.calculate(data[:400], data[401:500])
# Out:
# d:\a27_YEARS_OLD\data__validation\venv\Lib\site-packages\scipy\stats\_stats_py.py:7654: RuntimeWarning:
#
# divide by zero encountered in divide

# %%
data_drift_profile.json()
# Out:
# '{"data_drift": {"name": "data_drift", "datetime": "2024-12-21 16:26:12.322092", "data": {"utility_columns": {"date": null, "id": null, "target": null, "prediction": null}, "num_feature_names": ["no_of_employees", "prevailing_wage", "yr_of_estab"], "cat_feature_names": ["case_id", "case_status", "continent", "education_of_employee", "full_time_position", "has_job_experience", "region_of_employment", "requires_job_training", "unit_of_wage"], "text_feature_names": [], "datetime_feature_names": [], "target_names": null, "options": {"confidence": null, "drift_share": 0.5, "nbinsx": 10, "xbins": null}, "metrics": {"n_features": 12, "n_drifted_features": 2, "share_drifted_features": 0.16666666666666666, "dataset_drift": false, "no_of_employees": {"current_small_hist": {"x": [46.0, 11251.6, 22457.2, 33662.8, 44868.4, 56074.0, 67279.6, 78485.2, 89690.8, 100896.40000000001, 112102.0], "y": [8.383254260315729e-05, 9.014251892812612e-07, 9.014251892812611e-07, 9.014251892812614e-07, 0.0, 0.0, 0
# ...
